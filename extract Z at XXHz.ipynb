# %%
import pandas as pd
file_path = '/content/2024-02-26_14-18-05 cornV4-#15 sweep 20min 10-100kHz.xlsx'
new_file_path = '/content/new_file.xlsx'
df = pd.read_excel(file_path, sheet_name=0)
filtered_df = df[df.iloc[:, 0] == 1000] # change the frequency
filtered_df.to_excel(new_file_path, index=False)
